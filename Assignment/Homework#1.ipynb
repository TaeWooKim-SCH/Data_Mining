# %% [markdown]
# 문제에서 사용하는 모든 함수와 도움이 될 내용은 https://numpy.org/doc/stable/에서 찾아볼 수 있습니다.

# %% [markdown]
# 아래 코드를 실행시키면 다음과 같이 날짜가 빠진 부분이 출력이 됩니다.

# %%
import numpy as np

dates = np.arange(np.datetime64('2022-09-01'), np.datetime64('2022-09-27'), 2)
print(dates)

# P1. (10pt) numpy 함수만을 이용해서 빠진 날짜를 모두 출력하는 코드를 구현하세요.
print("P1")
dates2 = np.arange(np.datetime64('2022-09-02'), np.datetime64('2022-09-27'), 2)
print(dates2)

# P2. (10pt) for 구문을 이용해서 빠진 날자를 모두 출력하는 코드를 구현하세요.
    # 방법1: 리스트 이용
print("P2 - 방법1")
missing_date = []
for i in range(2, 27, 2):
    missing_date.append(np.datetime64('2022-09-{}'.format(str(i).zfill(2)))) # zfill(2): 1자리 숫자일때 0을 추가해 2자리수로 만들어줌. sting형일 때 가능
print(np.array(missing_date))

    # 방법2: 배열만 이용
print("P2 - 방법2")
missing_date =  np.arange(np.datetime64('2022-09-01'), np.datetime64('2022-09-27'), 2)
for i in range(2, 27, 2):
    missing_date = np.insert(missing_date, i - 1, np.datetime64('2022-09-{}'.format(str(i).zfill(2))))
missing_date = missing_date.reshape(-1, 2)
print(missing_date[:, 1])

    # 방법3: 배열만 이용
print("P2 - 방법3")
missing_date = np.zeros(13, dtype = "datetime64[D]")
x = 2
for i in range(13):
    missing_date[i] = np.datetime64('2022-09-{}'.format(str(x).zfill(2)))
    x += 2
print(missing_date)
# Out:
# ['2022-09-01' '2022-09-03' '2022-09-05' '2022-09-07' '2022-09-09'
#  '2022-09-11' '2022-09-13' '2022-09-15' '2022-09-17' '2022-09-19'
#  '2022-09-21' '2022-09-23' '2022-09-25']
# P1
# ['2022-09-02' '2022-09-04' '2022-09-06' '2022-09-08' '2022-09-10'
#  '2022-09-12' '2022-09-14' '2022-09-16' '2022-09-18' '2022-09-20'
#  '2022-09-22' '2022-09-24' '2022-09-26']
# P2 - 방법1
# ['2022-09-02' '2022-09-04' '2022-09-06' '2022-09-08' '2022-09-10'
#  '2022-09-12' '2022-09-14' '2022-09-16' '2022-09-18' '2022-09-20'
#  '2022-09-22' '2022-09-24' '2022-09-26']
# P2 - 방법2
# ['2022-09-02' '2022-09-04' '2022-09-06' '2022-09-08' '2022-09-10'
#  '2022-09-12' '2022-09-14' '2022-09-16' '2022-09-18' '2022-09-20'
#  '2022-09-22' '2022-09-24' '2022-09-26']
# P2 - 방법3
# ['2022-09-02' '2022-09-04' '2022-09-06' '2022-09-08' '2022-09-10'
#  '2022-09-12' '2022-09-14' '2022-09-16' '2022-09-18' '2022-09-20'
#  '2022-09-22' '2022-09-24' '2022-09-26']

# %% [markdown]
# P1. (10pt) numpy 함수만을 이용해서 빠진 날짜를 모두 출력하는 코드를 구현하세요.

# %% [markdown]
# P2. (10pt) for 구문을 이용해서 빠진 날자를 모두 출력하는 코드를 구현하세요.

# %% [markdown]
# numpy.where() 함수는 배열에서 조건에 맞는 요소의 인덱스를 반환합니다. 이를 이용해서 조건에 맞는 해당 인덱스로 원래의 배열로부터 부분 집합을 만들 수 있습니다.부분 집합을 만들기 위해서는 조건만 통과하면 튜플의 첫 번째 값에서 해당 배열 집합을 반환하고 두 번째 비어있는 조건을 무시해야 합니다. 그런 다음 반환된 인덱스를 사용하여 요소 자체의 배열을 가져올 수 있습니다.이러한 배경을 고려할 때, 다음 프로그램은 원래 주어진 배열에서 문자열 길이기 5보다 크거나 같은 문자열을 찾아서 배열 인텍스 위치와 해당 위치의 문자열로 부분집합들을 만듭니다.
#
# 다음 코드를 실행하고 결과를 확인하세요.

# %%
import numpy as np

phoenix= np.array("I'm a SCH student and I'm OK and I study all day".split(" "))
print(phoenix)
search_results, = np.where(np.char.str_len(phoenix) >=5)
print(search_results)
print(phoenix[search_results])

# P3. (10pt) 위 코드의 실행 결과로 얻은 부분 집합 요소인 문자열을
    # 1) 첫글자만 대문자로 변경하세요.
title_phoenix = phoenix[search_results]
for i in range(len(title_phoenix)):
    title_phoenix[i] = title_phoenix[i].title() # title(): 문자열의 첫 글자만 upper해줌
print(title_phoenix)

    #  2) 모두 대문자로 변경하세요.
upper_phoenix = phoenix[search_results]
for i in range(len(upper_phoenix)):
    upper_phoenix[i] = upper_phoenix[i].upper() # upper(): 문자열 전체를 대문자로 변경
print(upper_phoenix)


# P4. (10Pt) 어떻게 phoenix 배열에 있는 각 문자열을 시작과 끝에 별문자(*)로 묶을 수 있습니까? 코드로 구현하세요.
    # 방법1: 리스트 이용 - for문을 사용해 배열의 원소 양 끝에 "*"를 추가해주면 된다.
print("방법1")
phoenix= np.array("I'm a SCH student and I'm OK and I study all day".split(" "))
phoenix = list(phoenix) # array로 그대로 갖고 가면 student에서 끝에 별이 누락된다. 이유를 찾아봤지만 찾을 수 없었다.
for i in range(len(phoenix)):
    phoenix[i] = "*" + phoenix[i] + "*"
print(np.array(phoenix))

    # 방법2: 배열만 이용 - '*' 배열을 만들어줘서 phoenix 배열과 더해준다.
print("방법2")
phoenix= np.array("I'm a SCH student and I'm OK and I study all day".split(" "))
star = np.array(["*"] * len(phoenix))
star_phoenix = np.char.add(star, phoenix)
star_phoenix = np.char.add(star_phoenix, star)
print(star_phoenix)
# Out:
# ["I'm" 'a' 'SCH' 'student' 'and' "I'm" 'OK' 'and' 'I' 'study' 'all' 'day']
# [3 9]
# ['student' 'study']
# ['Student' 'Study']
# ['STUDENT' 'STUDY']
# 방법1
# ["*I'm*" '*a*' '*SCH*' '*student*' '*and*' "*I'm*" '*OK*' '*and*' '*I*'
#  '*study*' '*all*' '*day*']
# 방법2
# ["*I'm*" '*a*' '*SCH*' '*student*' '*and*' "*I'm*" '*OK*' '*and*' '*I*'
#  '*study*' '*all*' '*day*']

# %% [markdown]
# P3. (10pt) 위 코드의 실행 결과로 얻은 부분 집합 요소인 문자열을 1) 첫글자만 대문자로 변경하세요 2) 모두 대문자로 변경하세요.

# %% [markdown]
# P4. (10Pt) 어떻게 phoenix 배열에 있는 각 문자열을 시작과 끝에 별문자(*)로 묶을 수 있습니까? 코드로 구현하세요.

# %% [markdown]
# P5. (10 pts) 질문이 있나요?
# 당신이 강의에서나 교재 중에서 가장 잘 설명되었으면 하는 한가지는 무엇입니까? 한 두 줄로 요약해서 답변해주면 감사하겠습니다. 강의 중에나 온라인(상담,게시판등)을 통해서 해당 내용을 설명을 하겠습니다. (때때로 우리는 개념을 잘못 표현하여 사람들을 혼란스럽게 합니다. 때때로 우리는 사람들이 듣고 싶어하는 것들을 생략합니다. 때때로 책은 어떤 면에서 매우 혼란스럽습니다. 본인에게 그런 내용이 무엇이었는지 말할 기회입니다. 피드백을 환영합니다.)

# %% [markdown]
# - 저희가 수학에 있어서 부족한 부분이 많기 때문에 따로 수업 전에 공부하고 오면 좋은 개념을 올려주시거나 간단히 공부하기 좋은 수업에 도움되는 책을 추천해 주셨으면 좋겠습니다! 풀이가 긴 점 죄송합니다. 문제마다 여러가지 방법을 생각해봤습니다.
